# %% [raw]
# ---
# title: String networks
# jupyter:
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %%
#| echo: false
#| output: false

# %load_ext autoreload
# %autoreload 2

# %%
import geneinfo.string as gst

# %% [markdown]
# ## Show STRING interaction network

# %%
gst.show_string_network(['ATRX', 'TP53', 'RAD51'], nodes=10)
